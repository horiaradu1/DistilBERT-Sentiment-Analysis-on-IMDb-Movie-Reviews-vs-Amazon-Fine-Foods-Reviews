# %%
# Load Tensorboard Jupyter extension.
# %load_ext tensorboard

# %%
# Show NVIDIA info.
# !nvidia-smi

# %%
# Install requirements.
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: absl-py==1.0.0 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 1)) (1.0.0)
# Collecting aiohttp==3.8.1
#   Downloading aiohttp-3.8.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 1.1 MB/s eta 0:00:01
# Collecting aiosignal==1.2.0
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting asttokens==2.0.5
#   Downloading asttokens-2.0.5-py2.py3-none-any.whl (20 kB)
# Collecting async-timeout==4.0.2
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting attrs==21.4.0
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 3.2 MB/s eta 0:00:01
# Requirement already satisfied: backcall==0.2.0 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 7)) (0.2.0)
# Collecting black==22.3.0
#   Downloading black-22.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 5.5 MB/s eta 0:00:01
# Collecting cachetools==5.0.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting certifi==2021.10.8
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 4.2 MB/s eta 0:00:01
# Collecting charset-normalizer==2.0.12
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting click==8.1.3
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 4.1 MB/s eta 0:00:01
# Requirement already satisfied: cycler==0.11.0 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 13)) (0.11.0)
# Collecting datasets==2.2.1
#   Downloading datasets-2.2.1-py3-none-any.whl (342 kB)
#      |████████████████████████████████| 342 kB 1.0 MB/s eta 0:00:01
# Collecting debugpy==1.6.0
#   Downloading debugpy-1.6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 2.6 MB/s eta 0:00:01
# Collecting decorator==5.1.1
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting dill==0.3.4
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 3.2 MB/s eta 0:00:011
# Collecting entrypoints==0.4
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting executing==0.8.3
#   Downloading executing-0.8.3-py2.py3-none-any.whl (16 kB)
# Collecting filelock==3.6.0
#   Downloading filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Collecting fonttools==4.33.3
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      |████████████████████████████████| 930 kB 3.9 MB/s eta 0:00:01
# Collecting frozenlist==1.3.0
#   Downloading frozenlist-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      |████████████████████████████████| 158 kB 613 kB/s eta 0:00:01
# Collecting fsspec==2022.3.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 2.9 MB/s eta 0:00:01
# Collecting google-auth==2.6.6
#   Downloading google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 5.2 MB/s eta 0:00:01
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 25)) (0.4.6)
# Collecting grpcio==1.46.1
#   Downloading grpcio-1.46.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 544 kB/s eta 0:00:01
# Collecting huggingface-hub==0.6.0
#   Downloading huggingface_hub-0.6.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 840 kB/s eta 0:00:01
# Collecting idna==3.3
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 228 kB/s eta 0:00:01
# Collecting importlib-metadata==4.11.3
#   Downloading importlib_metadata-4.11.3-py3-none-any.whl (18 kB)
# Collecting ipykernel==6.13.0
#   Downloading ipykernel-6.13.0-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 2.0 MB/s eta 0:00:01
# Collecting ipython==8.3.0
#   Downloading ipython-8.3.0-py3-none-any.whl (750 kB)
#      |████████████████████████████████| 750 kB 4.1 MB/s eta 0:00:01
# Collecting jedi==0.18.1
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 2.7 MB/s eta 0:00:01
# Collecting jupyter-client==7.3.1
#   Downloading jupyter_client-7.3.1-py3-none-any.whl (130 kB)
#      |████████████████████████████████| 130 kB 3.2 MB/s eta 0:00:01
# Collecting jupyter-core==4.10.0
#   Downloading jupyter_core-4.10.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 2.7 MB/s eta 0:00:01
# Collecting kiwisolver==1.4.2
#   Downloading kiwisolver-1.4.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.6 MB/s eta 0:00:01
# Collecting Markdown==3.3.7
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 3.7 MB/s eta 0:00:011
# Requirement already satisfied: matplotlib==3.5.1 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 37)) (3.5.1)
# Requirement already satisfied: matplotlib-inline==0.1.3 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 38)) (0.1.3)
# Collecting multidict==6.0.2
#   Downloading multidict-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121 kB)
#      |████████████████████████████████| 121 kB 5.5 MB/s eta 0:00:01
# Collecting multiprocess==0.70.12.2
#   Downloading multiprocess-0.70.12.2-py38-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 5.8 MB/s eta 0:00:01
# Collecting mypy-extensions==0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting nest-asyncio==1.5.5
#   Downloading nest_asyncio-1.5.5-py3-none-any.whl (5.2 kB)
# Collecting numpy==1.22.3
#   Downloading numpy-1.22.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      |████████████████████████████████| 16.8 MB 3.1 MB/s eta 0:00:01
# Collecting oauthlib==3.2.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 4.3 MB/s eta 0:00:01
# Collecting opencv-python==4.5.5.64
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      |████████████████████████████████| 60.5 MB 239 kB/s eta 0:00:01
# Collecting packaging==21.3
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 1.7 MB/s eta 0:00:01
# Collecting pandas==1.4.2
#   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 6.7 MB/s eta 0:00:01
# Collecting parso==0.8.3
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 8.3 MB/s eta 0:00:01
# Collecting pathspec==0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: pexpect==4.8.0 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 50)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 51)) (0.7.5)
# Collecting Pillow==9.1.0
#   Downloading Pillow-9.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 21.7 MB/s eta 0:00:01
# Collecting platformdirs==2.5.2
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Collecting prompt-toolkit==3.0.29
#   Downloading prompt_toolkit-3.0.29-py3-none-any.whl (381 kB)
#      |████████████████████████████████| 381 kB 5.7 MB/s eta 0:00:01
# Collecting protobuf==3.20.1
#   Downloading protobuf-3.20.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 4.5 MB/s eta 0:00:01
# Collecting psutil==5.9.0
#   Downloading psutil-5.9.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#      |████████████████████████████████| 283 kB 8.4 MB/s eta 0:00:01
# Requirement already satisfied: ptyprocess==0.7.0 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 57)) (0.7.0)
# Collecting pure-eval==0.2.2
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting pyarrow==8.0.0
#   Downloading pyarrow-8.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      |████████████████████████████████| 29.4 MB 3.4 MB/s eta 0:00:011     |█████████████████               | 15.6 MB 13.2 MB/s eta 0:00:02
# Requirement already satisfied: pyasn1==0.4.8 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 60)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 61)) (0.2.8)
# Collecting pyDeprecate==0.3.2
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting Pygments==2.12.0
#   Downloading Pygments-2.12.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 8.4 MB/s eta 0:00:01
# Collecting pyparsing==3.0.8
#   Downloading pyparsing-3.0.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil==2.8.2 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 65)) (2.8.2)
# Collecting pytorch-lightning==1.6.3
#   Downloading pytorch_lightning-1.6.3-py3-none-any.whl (584 kB)
#      |████████████████████████████████| 584 kB 10.1 MB/s eta 0:00:01
# Collecting pytz==2022.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 10.0 MB/s eta 0:00:01
# Collecting PyYAML==6.0
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      |████████████████████████████████| 701 kB 13.5 MB/s eta 0:00:01
# Requirement already satisfied: pyzmq==22.3.0 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 69)) (22.3.0)
# Collecting regex==2022.4.24
#   Downloading regex-2022.4.24-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (764 kB)
#      |████████████████████████████████| 764 kB 4.4 MB/s eta 0:00:01
# Collecting requests==2.27.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s eta 0:00:011
# Collecting requests-oauthlib==1.3.1
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting responses==0.18.0
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: rsa==4.8 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 74)) (4.8)
# Collecting six==1.16.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting stack-data==0.2.0
#   Downloading stack_data-0.2.0-py3-none-any.whl (21 kB)
# Collecting tensorboard==2.9.0
#   Downloading tensorboard-2.9.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 12.7 MB/s eta 0:00:01
# Requirement already satisfied: tensorboard-data-server==0.6.1 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 78)) (0.6.1)
# Collecting tensorboard-plugin-wit==1.8.1
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 5.1 MB/s eta 0:00:01
# Collecting tokenizers==0.12.1
#   Downloading tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 643 kB/s eta 0:00:01
# Collecting tomli==2.0.1
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting torch==1.11.0
#   Downloading torch-1.11.0-cp38-cp38-manylinux1_x86_64.whl (750.6 MB)
#      |████████████████████████████████| 750.6 MB 33 kB/s  eta 0:00:014     |███████████████████             | 448.3 MB 7.7 MB/s eta 0:00:40     |███████████████████▎            | 452.0 MB 13.0 MB/s eta 0:00:23     |████████████████████            | 471.3 MB 7.9 MB/s eta 0:00:36     |████████████████████████        | 564.4 MB 9.5 MB/s eta 0:00:20     |█████████████████████████████▉  | 700.7 MB 12.2 MB/s eta 0:00:05     |███████████████████████████████▋| 741.2 MB 8.8 MB/s eta 0:00:02
# Collecting torchmetrics==0.8.2
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 7.2 MB/s eta 0:00:01
# Requirement already satisfied: tornado==6.1 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 84)) (6.1)
# Collecting tqdm==4.64.0
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 3.6 MB/s eta 0:00:011
# Collecting traitlets==5.2.0
#   Downloading traitlets-5.2.0-py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 7.6 MB/s eta 0:00:01
# Collecting transformers==4.19.0
#   Downloading transformers-4.19.0-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 7.8 MB/s eta 0:00:01
# Collecting typing_extensions==4.2.0
#   Downloading typing_extensions-4.2.0-py3-none-any.whl (24 kB)
# Collecting urllib3==1.26.9
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 12.7 MB/s eta 0:00:01
# Requirement already satisfied: wcwidth==0.2.5 in /home/horia/.local/lib/python3.8/site-packages (from -r ../requirements.txt (line 90)) (0.2.5)
# Collecting Werkzeug==2.1.2
#   Downloading Werkzeug-2.1.2-py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 9.6 MB/s eta 0:00:01
# Collecting xxhash==3.0.0
#   Downloading xxhash-3.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 11.7 MB/s eta 0:00:01
# Collecting yarl==1.7.2
#   Downloading yarl-1.7.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (308 kB)
#      |████████████████████████████████| 308 kB 9.4 MB/s eta 0:00:01
# Collecting zipp==3.8.0
#   Downloading zipp-3.8.0-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython==8.3.0->-r ../requirements.txt (line 31)) (45.2.0)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorboard==2.9.0->-r ../requirements.txt (line 77)) (0.34.2)
# ERROR: launchpadlib 1.10.13 requires testresources, which is not installed.
# ERROR: torchtext 0.11.0 has requirement torch==1.10.0, but you'll have torch 1.11.0 which is incompatible.
# ERROR: tensorflow 2.8.0 has requirement tensorboard<2.9,>=2.8, but you'll have tensorboard 2.9.0 which is incompatible.
# Installing collected packages: multidict, idna, yarl, frozenlist, aiosignal, attrs, charset-normalizer, async-timeout, aiohttp, six, asttokens, typing-extensions, click, tomli, mypy-extensions, platformdirs, pathspec, black, cachetools, certifi, filelock, PyYAML, urllib3, requests, pyparsing, packaging, tqdm, huggingface-hub, fsspec, numpy, pyarrow, pytz, pandas, responses, dill, xxhash, multiprocess, datasets, debugpy, decorator, entrypoints, executing, fonttools, google-auth, grpcio, zipp, importlib-metadata, nest-asyncio, traitlets, jupyter-core, jupyter-client, psutil, Pygments, prompt-toolkit, pure-eval, stack-data, parso, jedi, ipython, ipykernel, kiwisolver, Markdown, oauthlib, opencv-python, Pillow, protobuf, pyDeprecate, torch, torchmetrics, tensorboard-plugin-wit, Werkzeug, tensorboard, pytorch-lightning, regex, requests-oauthlib, tokenizers, transformers
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.2.0
#     Uninstalling attrs-21.2.0:
#       Successfully uninstalled attrs-21.2.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.0.1
#     Uninstalling typing-extensions-4.0.1:
#       Successfully uninstalled typing-extensions-4.0.1
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.2.4
#     Uninstalling cachetools-4.2.4:
#       Successfully uninstalled cachetools-4.2.4
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 2.4.7
#     Uninstalling pyparsing-2.4.7:
#       Successfully uninstalled pyparsing-2.4.7
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.5.0
#     Uninstalling debugpy-1.5.0:
#       Successfully uninstalled debugpy-1.5.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.0
#     Uninstalling decorator-5.1.0:
#       Successfully uninstalled decorator-5.1.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.28.3
#     Uninstalling fonttools-4.28.3:
#       Successfully uninstalled fonttools-4.28.3
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.3.3
#     Uninstalling google-auth-2.3.3:
#       Successfully uninstalled google-auth-2.3.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.8.2
#     Uninstalling importlib-metadata-4.8.2:
#       Successfully uninstalled importlib-metadata-4.8.2
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.1
#     Uninstalling nest-asyncio-1.5.1:
#       Successfully uninstalled nest-asyncio-1.5.1
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.0
#     Uninstalling traitlets-5.1.0:
#       Successfully uninstalled traitlets-5.1.0
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.8.1
#     Uninstalling jupyter-core-4.8.1:
#       Successfully uninstalled jupyter-core-4.8.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 7.0.6
#     Uninstalling jupyter-client-7.0.6:
#       Successfully uninstalled jupyter-client-7.0.6
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.10.0
#     Uninstalling Pygments-2.10.0:
#       Successfully uninstalled Pygments-2.10.0
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.20
#     Uninstalling prompt-toolkit-3.0.20:
#       Successfully uninstalled prompt-toolkit-3.0.20
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.2
#     Uninstalling parso-0.8.2:
#       Successfully uninstalled parso-0.8.2
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.18.0
#     Uninstalling jedi-0.18.0:
#       Successfully uninstalled jedi-0.18.0
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.28.0
#     Uninstalling ipython-7.28.0:
#       Successfully uninstalled ipython-7.28.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.4.1
#     Uninstalling ipykernel-6.4.1:
#       Successfully uninstalled ipykernel-6.4.1
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.3.2
#     Uninstalling kiwisolver-1.3.2:
#       Successfully uninstalled kiwisolver-1.3.2
#   Attempting uninstall: Markdown
#     Found existing installation: Markdown 3.3.6
#     Uninstalling Markdown-3.3.6:
#       Successfully uninstalled Markdown-3.3.6
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.5.3.56
#     Uninstalling opencv-python-4.5.3.56:
#       Successfully uninstalled opencv-python-4.5.3.56
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.3.2
#     Uninstalling Pillow-8.3.2:
#       Successfully uninstalled Pillow-8.3.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.1
#     Uninstalling protobuf-3.19.1:
#       Successfully uninstalled protobuf-3.19.1
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0
#     Uninstalling torch-1.10.0:
#       Successfully uninstalled torch-1.10.0
#   Attempting uninstall: tensorboard-plugin-wit
#     Found existing installation: tensorboard-plugin-wit 1.8.0
#     Uninstalling tensorboard-plugin-wit-1.8.0:
#       Successfully uninstalled tensorboard-plugin-wit-1.8.0
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.0.2
#     Uninstalling Werkzeug-2.0.2:
#       Successfully uninstalled Werkzeug-2.0.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: regex
#     Found existing installation: regex 2021.10.8
#     Uninstalling regex-2021.10.8:
#       Successfully uninstalled regex-2021.10.8
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 1.3.0
#     Uninstalling requests-oauthlib-1.3.0:
#       Successfully uninstalled requests-oauthlib-1.3.0
# Successfully installed Markdown-3.3.7 Pillow-9.1.0 PyYAML-6.0 Pygments-2.12.0 Werkzeug-2.1.2 aiohttp-3.8.1 aiosignal-1.2.0 asttokens-2.0.5 async-timeout-4.0.2 attrs-21.4.0 black-22.3.0 cachetools-5.0.0 certifi-2021.10.8 charset-normalizer-2.0.12 click-8.1.3 datasets-2.2.1 debugpy-1.6.0 decorator-5.1.1 dill-0.3.4 entrypoints-0.4 executing-0.8.3 filelock-3.6.0 fonttools-4.33.3 frozenlist-1.3.0 fsspec-2022.3.0 google-auth-2.6.6 grpcio-1.46.1 huggingface-hub-0.6.0 idna-3.3 importlib-metadata-4.11.3 ipykernel-6.13.0 ipython-8.3.0 jedi-0.18.1 jupyter-client-7.3.1 jupyter-core-4.10.0 kiwisolver-1.4.2 multidict-6.0.2 multiprocess-0.70.12.2 mypy-extensions-0.4.3 nest-asyncio-1.5.5 numpy-1.22.3 oauthlib-3.2.0 opencv-python-4.5.5.64 packaging-21.3 pandas-1.4.2 parso-0.8.3 pathspec-0.9.0 platformdirs-2.5.2 prompt-toolkit-3.0.29 protobuf-3.20.1 psutil-5.9.0 pure-eval-0.2.2 pyDeprecate-0.3.2 pyarrow-8.0.0 pyparsing-3.0.8 pytorch-lightning-1.6.3 pytz-2022.1 regex-2022.4.24 requests-2.27.1 requests-oauthlib-1.3.1 responses-0.18.0 six-1.16.0 stack-data-0.2.0 tensorboard-2.9.0 tensorboard-plugin-wit-1.8.1 tokenizers-0.12.1 tomli-2.0.1 torch-1.11.0 torchmetrics-0.8.2 tqdm-4.64.0 traitlets-5.2.0 transformers-4.19.0 typing-extensions-4.2.0 urllib3-1.26.9 xxhash-3.0.0 yarl-1.7.2 zipp-3.8.0

# %%
import datasets
import torch
import numpy as np
import pytorch_lightning as pl
import transformers
import torchmetrics
import gzip
import requests
import pandas as pd
import re
import os
import json
import yaml
import sys

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

from lib.data import load_amazon, load_imdb, stats, build_collate
from lib.train import train
from lib.test import test

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
root_dir = "logs"
val_ratio = 0.1
seed = 42

# %%
# Load IMDB dataset.
imdb_train, imdb_val, imdb_test = load_imdb(
    val_ratio=val_ratio, seed=seed, directory="../data/imdb"
)

# Load Amazon dataset.
amazon_train, amazon_val, amazon_test = load_amazon(
    train_size=len(imdb_train),
    val_size=len(imdb_val),
    test_size=len(imdb_test),
    seed=seed,
    directory="../data/amazon",
)
# Out:
# Loading dataset from [../data/imdb]
# Loading dataset from [../data/amazon]

# %%
print(
    f"IMDb:", len(imdb_train)+len(imdb_val)+len(imdb_test)
    )
stats(imdb_train, imdb_val, imdb_test)
print()
print(
    f"Amazon:", len(amazon_train)+len(amazon_val)+len(amazon_test)
    )
stats(amazon_train, amazon_val, amazon_test)
# Out:
# IMDb: 50000
# Train (22500)
# | Positive: 11250 (50.00%)
# | Negative: 11250 (50.00%)
# Val (2500)
# | Positive: 1250 (50.00%)
# | Negative: 1250 (50.00%)
# Test (25000)
# | Positive: 12500 (50.00%)
# | Negative: 12500 (50.00%)
#
# Amazon: 50000
# Train (22500)
# | Positive: 11250 (50.00%)
# | Negative: 11250 (50.00%)
# Val (2500)
# | Positive: 1250 (50.00%)
# | Negative: 1250 (50.00%)
# Test (25000)
# | Positive: 12500 (50.00%)
# | Negative: 12500 (50.00%)

# %%
# Load train configs.
with open("../experiments/train.yaml", "r") as f:
    train_config = yaml.safe_load(stream=f)
train_experiments = [
    {**train_config["common"], **experiment}
    for experiment in train_config["experiments"]
]

# Load test configs.
with open("../experiments/test.yaml", "r") as f:
    test_config = yaml.safe_load(stream=f)
test_experiments = [
    {**test_config["common"], **experiment} for experiment in test_config["experiments"]
]

# %%
# Clear cache and checkpoint logs.
# !rm -rf logs
# !rm -rf /tmp/.tensorboard-info

# %%
# Launch Tensorboard session.
# %tensorboard --logdir=logs
# Out:
#       <iframe id="tensorboard-frame-9ea45048acbdcc3a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9ea45048acbdcc3a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Run train experiments.
for experiment_args in train_experiments:
    if experiment_args["dataset"] == "imdb":
        train(**experiment_args, train_dataset=imdb_train, val_dataset=imdb_val)
    elif experiment_args["dataset"] == "amazon":
        train(**experiment_args, train_dataset=amazon_train, val_dataset=amazon_val)
    else:
        raise ValueError(f"Unknown dataset: {experiment_args['dataset']}")

# %%
# Run test experiments.
for experiment_args in test_experiments:
    if experiment_args["dataset"] == "imdb":
        test(**experiment_args, test_dataset=imdb_test)
    elif experiment_args["dataset"] == "amazon":
        test(**experiment_args, test_dataset=amazon_test)
    else:
        raise ValueError(f"Unknown dataset: {experiment_args['dataset']}")
